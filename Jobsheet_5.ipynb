# %% [markdown]
# <a href="https://colab.research.google.com/github/Agtna/AI-2025/blob/main/Jobsheet_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import datetime as dt

# %% [markdown]
# ## Data Understanding
# - Load dataset
# ---

# %%
# Customers

df_customers= pd.read_csv('./customers.csv')
df_customers
# Out:
#        CustomerID Segment Currency
# 0               3     SME      EUR
# 1               5     LAM      EUR
# 2               6     SME      EUR
# 3               7     LAM      EUR
# 4               9     SME      EUR
# ...           ...     ...      ...
# 32456       53307     SME      CZK
# 32457       53309     SME      CZK
# 32458       53311     SME      CZK
# 32459       53313     SME      CZK
# 32460       53314     SME      CZK
#
# [32461 rows x 3 columns]

# %%
# Gas Stations

df_gasstations = pd.read_csv('./gasstations.csv')
df_gasstations
# Out:
#       GasStationID  ChainID Country          Segment
# 0               44       13     CZE  Value for money
# 1               45        6     CZE          Premium
# 2               46       23     CZE            Other
# 3               47       33     CZE          Premium
# 4               48        4     CZE          Premium
# ...            ...      ...     ...              ...
# 5711          5768        3     CZE            Other
# 5712          5769      153     SVK            Other
# 5713          5770        6     CZE          Premium
# 5714          5771        2     CZE           Noname
# 5715          5772       16     CZE            Other
#
# [5716 rows x 4 columns]

# %%
# Products

df_products = pd.read_csv('./products.csv')
df_products
# Out:
#      ProductID                      Description
# 0            1                     Rucní zadání
# 1            2                            Nafta
# 2            3                          Special
# 3            4                            Super
# 4            5                          Natural
# ..         ...                              ...
# 586        602                              CNG
# 587        603                     Ethanol E-85
# 588        604                Zprostredk.nakupu
# 589        605      Replacement of UTA MultiBox
# 590        630  CCS Carnet Pronájem HW (Manual)
#
# [591 rows x 2 columns]

# %%
# Transactions

df_transactions = pd.read_csv('./transactions_1k.csv')
df_transactions
# Out:
#      TransactionID        Date      Time  CustomerID  CardID  GasStationID  \
# 0                1  2012-08-24  09:41:00       31543  486621          3704
# 1                2  2012-08-24  10:03:00       46707  550134          3704
# 2                3  2012-08-24  10:03:00       46707  550134          3704
# 3                4  2012-08-24  13:53:00        7654  684220           656
# 4                5  2012-08-24  08:49:00       17373  536109           741
# ..             ...         ...       ...         ...     ...           ...
# 995            996  2012-08-26  13:04:00       12021  692529          3750
# 996            997  2012-08-26  11:52:00       15618  602037           438
# 997            998  2012-08-26  12:31:00       47057  533108           438
# 998            999  2012-08-25  07:51:00       22994  602354          3899
# 999           1000  2012-08-25  12:45:00       25986  655214          3899
#
#      ProductID  Amount   Price
# 0            2      28  672.64
# ...

# %%
# Year Month

df_yearmonth = pd.read_csv('./yearmonth.csv')
df_yearmonth
# Out:
#         CustomerID    Date  Consumption
# 0                5  201207       528.30
# 1                5  201302      1598.28
# 2                5  201303      1931.36
# 3                5  201304      1497.14
# 4                6  201203        51.06
# ...            ...     ...          ...
# 383277       52309  201311       138.61
# 383278       52312  201310        78.19
# 383279       52322  201311       125.30
# 383280       52331  201311      3849.73
# 383281       52353  201311      1566.24
#
# [383282 rows x 3 columns]

# %% [markdown]
# ## Data Understanding
# - Preview dataset
# ---

# %%
df_customer = pd.read_csv('customers.csv')
df_customer.head()
# Out:
#    CustomerID Segment Currency
# 0           3     SME      EUR
# 1           5     LAM      EUR
# 2           6     SME      EUR
# 3           7     LAM      EUR
# 4           9     SME      EUR

# %%
df_gasstations = pd.read_csv('gasstations.csv')
df_gasstations.head()
# Out:
#    GasStationID  ChainID Country          Segment
# 0            44       13     CZE  Value for money
# 1            45        6     CZE          Premium
# 2            46       23     CZE            Other
# 3            47       33     CZE          Premium
# 4            48        4     CZE          Premium

# %%
df_products = pd.read_csv('products.csv')
df_products.head()
# Out:
#    ProductID   Description
# 0          1  Rucní zadání
# 1          2         Nafta
# 2          3       Special
# 3          4         Super
# 4          5       Natural

# %%
df_transactions = pd.read_csv('transactions_1k.csv')
df_transactions.head()
# Out:
#    TransactionID        Date      Time  CustomerID  CardID  GasStationID  \
# 0              1  2012-08-24  09:41:00       31543  486621          3704
# 1              2  2012-08-24  10:03:00       46707  550134          3704
# 2              3  2012-08-24  10:03:00       46707  550134          3704
# 3              4  2012-08-24  13:53:00        7654  684220           656
# 4              5  2012-08-24  08:49:00       17373  536109           741
#
#    ProductID  Amount   Price
# 0          2      28  672.64
# 1          2      18  430.72
# 2         23       1  121.99
# 3          5       5  120.74
# 4          2      28  645.05

# %% [markdown]
# ## Data Understanding
# - Merge tables
# ---

# %%
df_merge1 = pd.merge(df_transactions, df_customers, on='CustomerID', how='left')
df_merge2 = pd.merge(df_merge1, df_gasstations, on='GasStationID', how='left')
df_merged = pd.merge(df_merge2, df_products, on='ProductID', how='left')

df_merged.head()
# Out:
#    TransactionID        Date      Time  CustomerID  CardID  GasStationID  \
# 0              1  2012-08-24  09:41:00       31543  486621          3704
# 1              2  2012-08-24  10:03:00       46707  550134          3704
# 2              3  2012-08-24  10:03:00       46707  550134          3704
# 3              4  2012-08-24  13:53:00        7654  684220           656
# 4              5  2012-08-24  08:49:00       17373  536109           741
#
#    ProductID  Amount   Price Segment_x Currency  ChainID Country Segment_y  \
# 0          2      28  672.64       KAM      CZK        4     CZE   Premium
# 1          2      18  430.72       KAM      CZK        4     CZE   Premium
# 2         23       1  121.99       KAM      CZK        4     CZE   Premium
# 3          5       5  120.74       KAM      CZK       30     CZE    Noname
# 4          2      28  645.05       KAM      CZK        2     CZE    Noname
#
#     Description
# 0         Nafta
# 1         Nafta
# 2  Provoz.nápl.
# ...

# %% [markdown]
# ## Data Understanding
# - Preview Data types
# ---

# %%
df_merged.dtypes
# Out:
# TransactionID      int64
# Date              object
# Time              object
# CustomerID         int64
# CardID             int64
# GasStationID       int64
# ProductID          int64
# Amount             int64
# Price            float64
# Segment_x         object
# Currency          object
# ChainID            int64
# Country           object
# Segment_y         object
# Description       object
# dtype: object

# %% [markdown]
# ## Soal-1
# Buatlah table list Top 5 Customers yang memiliki nilai transaksi paling banyak
# ---

# %%
# Filter untuk hanya menampilkan baris dengan TransactionID 1, 2, 76, 77, dan 78
filtered_df = df_merged[df_merged['TransactionID'].isin([1, 2, 76, 77, 78])].reset_index(drop=True)

# Tampilkan hasil
filtered_df
# Out:
#    TransactionID        Date      Time  CustomerID  CardID  GasStationID  \
# 0              1  2012-08-24  09:41:00       31543  486621          3704
# 1              2  2012-08-24  10:03:00       46707  550134          3704
# 2             76  2012-08-24  08:40:00       30815  555003          1155
# 3             77  2012-08-24  09:18:00       41875  595023          1155
# 4             78  2012-08-24  10:12:00        6067  450132          1155
#
#    ProductID  Amount   Price Segment_x Currency  ChainID Country Segment_y  \
# 0          2      28  672.64       KAM      CZK        4     CZE   Premium
# 1          2      18  430.72       KAM      CZK        4     CZE   Premium
# 2          2      27  624.40       LAM      CZK        4     CZE   Premium
# 3          2      23  528.13       KAM      CZK        4     CZE   Premium
# 4          2       9  197.87       KAM      CZK        4     CZE   Premium
#
#   Description
# 0       Nafta
# 1       Nafta
# 2       Nafta
# ...

# %% [markdown]
# ## Soal-2
# Buatlah list Top 5 Gas stations yang memiliki nilai transaksi paling banyak
# ---

# %%
df_gasstations = df_merged.groupby('GasStationID')
df_top5_station = df_gasstations[['Amount', 'Price']].sum()
df_top5_station.rename(columns={'Price':'Gas Sales'}, inplace=True)
df_top5_station.sort_values(by='Gas Sales', ascending=False).head()

# %% [markdown]
# ## Soal-3
# Buatlah list Top 5 Jenis produk yang memiliki nilai transaksi paling banyak
# ---

# %%
df_products = df_merged.groupby('Description')
df_top5_product = df_products[['Amount', 'Price']].sum()
df_top5_product.rename(columns={'Price':'Sales'}, inplace=True)
df_top5_product.sort_values(by='Sales', ascending=False).head()

# %% [markdown]
# ## Soal-4
# Buatlah deskripsi statistik untuk masing masing hari (23,24,25,26) pada dataset transaction_1k
# ---

# %%
df = df_transactions.copy()
df['Date'] = pd.to_datetime(df['Date'])
df['Date'] = df['Date'].dt.day
filtered_df = df[df['Date'].isin([23, 24, 25, 26])]
daily_stats= filtered_df.groupby('Date')[['Amount', 'Price']].describe()
daily_stats

# %% [markdown]
# ## Soal-5
# Carilah waktu terbaik (hari dan jam) dimana paling banyak user gas station melakukan transaksi
# ---

# %%
print(df['Date'].head())
print(df['Date'].dtype)

# %%
df = df_transactions.copy()
print(df['Date'].head())
df['Date'] = pd.to_datetime(df['Date'])  # konversi lagi jika masih format string

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Hour'] = pd.to_datetime(df['Time'], format='%H:%M:%S').dt.hour
df_grouped = df.groupby(['Date', 'Hour']).agg({
    'Amount': 'sum', 'Price': 'sum'}).rename(columns={'Price': 'Gas Sales'})
df_grouped

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Hour'] = pd.to_datetime(df['Time'], format='%H:%M:%S').dt.hour
df_grouped = df.groupby(['Date', 'Hour']).agg({
    'Amount': 'sum', 'Price': 'sum'}).rename(columns={'Price': 'Gas Sales'})
best_times = df_grouped.reset_index().sort_values(['Date', 'Amount'], ascending=[True, False])
best_per_day = best_times.groupby('Date').first().reset_index()
best_per_day.set_index('Date', inplace=True)
best_per_day
